# %%
import numpy as np
import matplotlib.pyplot as plt 
# %pylab inline
names = ['0.125', '0.25', '0.5', '1.0', '2.0']
x = range(len(names))
#x1=[0.125, 0.25, 0.5, 1.0, 2.0]
#y1=[1.1236445042593783, 0.9445228741551193, 0.8076268467118396, 0.7338632938664141, 0.8554906334086667]
y1=[1.181509775442734, 0.9990655971694344, 0.888804426997693, 0.8782516398731535, 0.9524860331392989]
x2=[0.125, 0.25, 0.5, 1.0, 2.0]
y2=[0.3787085791029217, 0.3286519838206603, 0.2712531786681275, 0.21934248631366193, 0.16622486350795662]
x3=[0.125, 0.25, 0.5, 1.0, 2.0]
y3=[0.24872894171930948,0.193430535396666,0.16926678338835183,0.1358705231079043,0.1245846667019997]
#x=np.arange(20,350)
l1=plt.plot(x,y1,'r--',label='Dual Query')
l2=plt.plot(x,y2,'g--',label='PrivBayes')
l3=plt.plot(x,y3,'b--',label='GM')
plt.plot(x,y1,'ro-',x,y2,'go-',x,y3,'b^-')
plt.xticks(x, names, rotation=45)
plt.title('Comparation with Dual Query, PrivBayes')
plt.xlabel('Epsilon')
plt.ylabel('Workload Error')
plt.legend()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# $P(A,B,C,D,E,F)$

# %% [markdown]
# $\frac{1}{Z} \cdot \phi_{ABC} \cdot \phi_{BCE} \cdot \phi_{BD} \cdot \phi_{BEF} \cdot \phi_{BEF}$

# %% [markdown]
# $\approx$
